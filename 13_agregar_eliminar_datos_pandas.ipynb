# %%
import pandas as pd

# %%
df_books =pd.read_csv('https://raw.githubusercontent.com/sanketchavan5595/EDA-on-bestselling-books-on-Amazon-/main/bestsellers%20with%20categories.csv')
df_books.head(2) #muestra solo las dos primeras filas
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %%
df_books.drop('Genre', axis=1).head(2) #elimina el atributo 'Genre' en el eje de las columnas (1)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year
# 0  2016
# 1  2011

# %%
df_books.head(2) #no se aplican los cambios
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year        Genre
# 0  2016  Non Fiction
# 1  2011      Fiction

# %%
df_books.drop('Genre', axis=1, inplace=True) #elimina el atributo 'Genre' en el eje de las columnas (1), y lo aplica al DataFrame

# %%
df_books.head(2)
# Out:
#                             Name        Author  User Rating  Reviews  Price  \
# 0  10-Day Green Smoothie Cleanse      JJ Smith          4.7    17350      8
# 1              11/22/63: A Novel  Stephen King          4.6     2052     22
#
#    Year
# 0  2016
# 1  2011

# %%
df_books =df_books.drop('Year', axis=1) #sinónimo

# %%
del df_books['Price'] #sinónimo (este método no pertenece a pandas, no se recomienda)

# %%
df_books.head(4)
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
# 3                   1984 (Signet Classics)       George Orwell          4.7
#
#    Reviews
# 0    17350
# 1     2052
# 2    18979
# 3    21424

# %%
df_books.drop(0, axis=0).head(4) #elimina la fila (0) de indice 0
# Out:
#                                                 Name  \
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews
# 1              Stephen King          4.6     2052
# 2        Jordan B. Peterson          4.7    18979
# 3             George Orwell          4.7    21424
# 4  National Geographic Kids          4.8     7665

# %%
df_books.drop([0,1,2,3], axis=0).head(4) #elimina las filas (0) de indice 0,1,2,3
# Out:
#                                                 Name  \
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
# 6  A Game of Thrones / A Clash of Kings / A Storm...
# 7                     A Gentleman in Moscow: A Novel
#
#                      Author  User Rating  Reviews
# 4  National Geographic Kids          4.8     7665
# 5       George R. R. Martin          4.4    12643
# 6       George R. R. Martin          4.7    19735
# 7               Amor Towles          4.7    19699

# %%
df_books.drop(range(0,20), axis=0).head(4) #elimina las filas (0) de indices entre 0 y 20 (excluyendo el indice final)
# Out:
#                                                  Name         Author  \
# 20                        All the Light We Cannot See  Anthony Doerr
# 21                        All the Light We Cannot See  Anthony Doerr
# 22                                          Allegiant  Veronica Roth
# 23  American Sniper: The Autobiography of the Most...     Chris Kyle
#
#     User Rating  Reviews
# 20          4.6    36348
# 21          4.6    36348
# 22          3.9     6310
# 23          4.6    15921

# %% [markdown]
# Agregar

# %%
import numpy as np

# %%
df_books['new_column'] =np.nan #agrega nueva columna, en este caso con un no numerico
df_books.head(4)
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                        11/22/63: A Novel        Stephen King          4.6
# 2  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
# 3                   1984 (Signet Classics)       George Orwell          4.7
#
#    Reviews  new_column
# 0    17350         NaN
# 1     2052         NaN
# 2    18979         NaN
# 3    21424         NaN

# %%
nb_rows =df_books.shape[0] #número de filas
ran =range(0, nb_rows)
df_books['range'] =ran #insertando un rango como nuevo columna
df_books.head(10)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
# 6  A Game of Thrones / A Clash of Kings / A Storm...
# 7                     A Gentleman in Moscow: A Novel
# 8      A Higher Loyalty: Truth, Lies, and Leadership
# 9                          A Man Called Ove: A Novel
#
#                      Author  User Rating  Reviews  new_column  range
# 0                  JJ Smith          4.7    17350         NaN      0
# 1              Stephen King          4.6     2052         NaN      1
# 2        Jordan B. Peterson          4.7    18979         NaN      2
# 3             George Orwell          4.7    21424         NaN      3
# ...

# %%
df_books.shape
# Out:
# (550, 6)

# %%
df_books =df_books.append(df_books) #agregando filas, las mismas nuevamente
df_books.shape #filas duplicadas
# Out:
# (2200, 6)
