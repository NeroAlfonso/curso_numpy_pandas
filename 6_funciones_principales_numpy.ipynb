# %%
import numpy as np

# %%
vector =np.random.randint(1, 20, 10)
vector
# Out:
# array([ 8, 16,  5,  4, 11, 17, 12, 19, 12,  6])

# %%
matriz =vector.reshape(2,5)
matriz
# Out:
# array([[ 8, 16,  5,  4, 11],
#        [17, 12, 19, 12,  6]])

# %%
vector.max() #número mas grande del vector
# Out:
# 19

# %%
matriz.max() # || de la matriz
# Out:
# 19

# %%
matriz.max(1) #mayor por el eje 1 (filas)
# Out:
# array([16, 19])

# %%
matriz.max(0) #mayor por el eje 0 (columnas)
# Out:
# array([17, 16, 19, 12, 11])

# %%
vector.argmax() #indice donde se encuentra el valor mas grande del vector (con preferencia del indice mas bajo)
# Out:
# 7

# %%
matriz.argmax(0) # ||, en el eje 0 (columnas)
# Out:
# array([1, 0, 1, 1, 0])

# %% [markdown]
# - min y argmin son esencialmente lo contrario a max y argmax

# %%
vector.min()
# Out:
# 4

# %%
matriz.min()
# Out:
# 4

# %%
vector.argmin()
# Out:
# 3

# %%
matriz.argmin(0)
# Out:
# array([0, 1, 0, 0, 1])

# %%
vector
# Out:
# array([ 8, 16,  5,  4, 11, 17, 12, 19, 12,  6])

# %%
vector.ptp() #diferencia entre el pico mas alto y el mas bajo
# Out:
# 15

# %%
matriz
# Out:
# array([[ 8, 16,  5,  4, 11],
#        [17, 12, 19, 12,  6]])

# %%
matriz.ptp()
# Out:
# 15

# %%
matriz.ptp(0)
# Out:
# array([ 9,  4, 14,  8,  5])

# %%
vector
# Out:
# array([ 8, 16,  5,  4, 11, 17, 12, 19, 12,  6])

# %%
np.percentile(vector, 50) #valor que se encuentra en la mitad (la mediana)
# Out:
# 11.5

# %%
np.percentile(vector, 0) #mas bajo
# Out:
# 4.0

# %%
np.percentile(vector, 100) #mas alto
# Out:
# 19.0

# %%
vector.sort() #ordena de menor a mayor los valores
vector
# Out:
# array([ 4,  5,  6,  8, 11, 12, 12, 16, 17, 19])

# %%
np.median(vector) #la mediana
# Out:
# 11.5

# %%
np.median(matriz, 0) #mediana del eje cero
# Out:
# array([ 8. ,  8.5, 11. , 12.5, 15. ])

# %%
np.std(vector) #desviación estándar o típica
# Out:
# 4.959838707054898

# %%
np.var(vector) #varianza
# Out:
# 24.6

# %%
np.std(vector) **2 #la desviación estándar elevada al cuadrado es igual a la varianza
# Out:
# 24.599999999999998

# %%
import math

# %%
math.sqrt(np.var(vector)) #la raíz cuadrada de la varianza es la desviación estándar
# Out:
# 4.959838707054898

# %%
np.mean(vector) #media (promedio)
# Out:
# 11.0

# %%
matriza =np.array([[1,2], [3,4]])
matrizb =np.array([5,6])

# %%
matriza, matrizb
# Out:
# (array([[1, 2],
#         [3, 4]]), array([[5, 6]]))

# %%
#np.concatenate((matriza, matrizb), axis=0) #no cuentan con la misma cantidad de dimensiones por lo tanto no se pueden cocatenar

# %%
matriza.ndim, matrizb.ndim
# Out:
# (2, 1)

# %%
matrizb =np.expand_dims(matrizb, axis=0)

# %%
np.concatenate((matriza, matrizb), axis=0) #se concatenan las matrices en el eje cero (columnas)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
#np.concatenate((matriza, matrizb), axis=1) #si quisieramos contatenar en el eje 1 (filas) nos dá un error, por la disposición de los valores

# %%
#se podría manejar con un reshape

# %%
matrizb, matrizb.T #o con la transpuesta (cambia la matriz de 1x2 a 2x1)
# Out:
# (array([[5, 6]]), array([[5],
#         [6]]))

# %%
np.concatenate((matriza, matrizb.T), axis=1) #se concatenan correctamente con el uso de la transpuesta
# Out:
# array([[1, 2, 5],
#        [3, 4, 6]])
