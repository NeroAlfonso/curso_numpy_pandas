# %%
import numpy as np

# %%
array =np.array([1,2,3,4])
array
# Out:
# array([1, 2, 3, 4])

# %%
array.dtype #tipo de datos del array
# Out:
# dtype('int64')

# %%
array_f =np.array([1,2,3,4], dtype='float64') #establecer el tipo del array
array_f.dtype
# Out:
# dtype('float64')

# %%
array =array.astype(np.float64) #refundir un array en flotante
array.dtype
# Out:
# dtype('float64')

# %%
array= array.astype(np.bool_)
array
# Out:
# array([ True,  True,  True,  True])

# %%
array =array.astype(np.string_)
array
# Out:
# array([b'True', b'True', b'True', b'True'], dtype='|S5')

# %%
array =np.array(['0','1','2','3'])
array
# Out:
# array(['0', '1', '2', '3'], dtype='<U1')

# %%
array = array.astype(np.int8)
array
# Out:
# array([0, 1, 2, 3], dtype=int8)

# %%
array = np.array(['dsa', '2', '4'])
#array = array.astype(np.int8) #error de refundición

# %%
#los arrays de numpy solo pueden tener un solo tipo de datos
