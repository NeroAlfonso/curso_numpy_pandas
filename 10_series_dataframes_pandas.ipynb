# %%
import pandas as pd

# %% [markdown]
# Pandas
# Series     =Vectores
# DataFrames =Matrices
#
# Basado en numpy

# %%
players =pd.Series(['Juan', 'Martin', 'Maria', 'Paula'],
          index=[1,4,5,6]) #crea una serie con los indices suministrados
players
# Out:
# 1      Juan
# 4    Martin
# 5     Maria
# 6     Paula
# dtype: object

# %%
players2 =pd.Series(['Juan', 'Martin', 'Maria', 'Paula']) 
players2
# Out:
# 0      Juan
# 1    Martin
# 2     Maria
# 3     Paula
# dtype: object

# %%
dic ={1:'Juan', 4:'Martin', 5:'Maria', 6:'Paula'}
dic
# Out:
# {1: 'Juan', 4: 'Martin', 5: 'Maria', 6: 'Paula'}

# %%
pd.Series(dic) #sinonimo, con un diccionario de python
# Out:
# 1      Juan
# 4    Martin
# 5     Maria
# 6     Paula
# dtype: object

# %%
#players[0] #indice no existe

# %%
players[4]
# Out:
# 'Martin'

# %%
players[0:3] #slice
# Out:
# 1      Juan
# 4    Martin
# 5     Maria
# dtype: object

# %%
dic ={'Jugador':['Juan', 'Martin', 'Maria', 'Paula'],'Altura':[183,190,150,163], 'Ganadas':[10,12,5,24]}
dic
# Out:
# {'Jugador': ['Juan', 'Martin', 'Maria', 'Paula'],
#  'Altura': [183, 190, 150, 163],
#  'Ganadas': [10, 12, 5, 24]}

# %%
players_dataframe =pd.DataFrame(dic,index=[1,4,5,6]) #creamos un dataframe a partir de un diccionario de python
players_dataframe
# Out:
#   Jugador  Altura  Ganadas
# 1    Juan     183       10
# 4  Martin     190       12
# 5   Maria     150        5
# 6   Paula     163       24

# %%
players_dataframe.index #indices
# Out:
# Int64Index([1, 4, 5, 6], dtype='int64')

# %%
players_dataframe.columns #columnas
# Out:
# Index(['Jugador', 'Altura', 'Ganadas'], dtype='object')
