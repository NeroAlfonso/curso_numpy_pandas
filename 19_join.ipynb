# %%
import pandas as pd

# %%
df_left =pd.DataFrame({'A':['A0','A1','A2'],
  'B':['B0','B1','B2']},
  index=['k0','k1','k2'])
df_right =pd.DataFrame({
    'C':['C0','C1','C2'],
    'D':['D0','D1','D2']
}, index=['k0','k2','k3'])

# %% [markdown]
# ## Join - index match

# %%
df_left.join(df_right) #fusiona en función del index
# Out:
#      A   B    C    D
# k0  A0  B0   C0   D0
# k1  A1  B1  NaN  NaN
# k2  A2  B2   C1   D1

# %%
df_left.join(df_right, how='inner')
# Out:
#      A   B   C   D
# k0  A0  B0  C0  D0
# k2  A2  B2  C1  D1

# %%
df_left.join(df_right, how='left')
# Out:
#      A   B    C    D
# k0  A0  B0   C0   D0
# k1  A1  B1  NaN  NaN
# k2  A2  B2   C1   D1

# %%
df_left.join(df_right, how='right')
# Out:
#       A    B   C   D
# k0   A0   B0  C0  D0
# k2   A2   B2  C1  D1
# k3  NaN  NaN  C2  D2

# %%
df_left.join(df_right, how='outer')
# Out:
#       A    B    C    D
# k0   A0   B0   C0   D0
# k1   A1   B1  NaN  NaN
# k2   A2   B2   C1   D1
# k3  NaN  NaN   C2   D2
